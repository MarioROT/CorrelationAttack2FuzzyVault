# %% [markdown]
# # Fuzzy Vault Datasets Statistics

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.path import Path
import matplotlib.patches as patches
from pylab import *
import itertools
from sklearn.metrics import confusion_matrix
from PlotUtils import *
import pathlib
import scipy.io

# Para cambiar el mapa de color por defecto
plt.rcParams["image.cmap"] = "Set2"
# Para cambiar el ciclo de color por defecto en Matplotlib
# plt.rcParams['axes.prop_cycle'] = plt.cycler(color=plt.cm.Set2.colors)
plt.rcParams["axes.prop_cycle"] =  plt.cycler('color', ['#8C6D31', '#ffdd6b', '#e9e2c9', '#dcae52', '#af7132', '#8C9363', '#637939', '#AD494A', '#E7969C', '#C4CBB9'])
# plt.rcParams["axes.prop_cycle"] =  plt.cycler('color', ['#081d58', '#253494', '#225ea8', '#1d91c0', '#41b6c4', '#7fcdbb', '#c7e9b4', '#edf8b1', '#ffffd9'])
# plt.rcParams["axes.prop_cycle"] =  plt.cycler('color', ['#084081', '#0868ac', '#2b8cbe', '#4eb3d3', '#7bccc4', '#a8ddb5', '#ccebc5', '#e0f3db', '#f7fcf0'])
# plt.rcParams["axes.prop_cycle"] =  plt.cycler('color', ['#67001f', '#b2182b', '#d6604d', '#f4a582', '#fddbc7', '#d1e5f0', '#92c5de', '#4393c3', '#2166ac','#053061'])
# plt.rcParams["axes.prop_cycle"] =  plt.cycler('color', ['#67001f', '#053061', '#b2182b', '#2166ac', '#d6604d', '#4393c3', '#f4a582', '#92c5de', '#fddbc7','#d1e5f0'])
# plt.rcParams["axes.prop_cycle"] =  plt.cycler('color', ['#67001f', '#053061', '#b2182b', '#2166ac', '#d6604d', '#4393c3', '#f4a582', '#92c5de', '#fddbc7','#d1e5f0'][::-1])
# plt.rcParams["axes.prop_cycle"] =  plt.cycler('color', ['#8dd3c7', '#ffffb3', '#bebada', '#fb8072', '#80b1d3', '#fdb462', '#b3de69', '#fccde5', '#d9d9d9','#bc80bd','#ccebc5','#ffed6f'])
# plt.rcParams["axes.prop_cycle"] =  plt.cycler('color', ['#8dd3c7', '#ffffb3', '#bebada', '#fb8072', '#80b1d3', '#fdb462', '#b3de69', '#fccde5', '#d9d9d9','#bc80bd','#ccebc5','#ffed6f'][::-1])

# %% [markdown]
# ### Resultados Sin Translaciones

# %%
rsl10md = pd.read_csv('ExpResults/TabResCorr10mindistSoloGiro.csv')
rsl10md = rsl10md.T.reset_index()
rsl10md.columns= ['Distancia', 'Puntos encontrados promedio', 'Puntos genuinos encontrados promedio', 'Número de emparejamientos que se podrían vulnerar', 'Iteraciones promedio necesarias para vulnerar']
rsl10md = rsl10md.round({'Distancia':3, 'Puntos encontrados promedio':3, 'Puntos genuinos encontrados promedio':3, 'Número de emparejamientos que se podrían vulnerar':3, 'Iteraciones promedio necesarias para vulnerar':3})

rsl20md = pd.read_csv('ExpResults/TabResCorr10_3000_6000mindistSoloGiro.csv')
rsl20md = rsl20md.T.reset_index()
rsl20md.columns= ['Distancia', 'Puntos encontrados promedio', 'Puntos genuinos encontrados promedio', 'Número de emparejamientos que se podrían vulnerar', 'Iteraciones promedio necesarias para vulnerar']
rsl20md = rsl20md[1:]
rsl20md = rsl20md.round({'Distancia':3, 'Puntos encontrados promedio':3, 'Puntos genuinos encontrados promedio':3, 'Número de emparejamientos que se podrían vulnerar':3, 'Iteraciones promedio necesarias para vulnerar':3})

rsl30md = pd.read_csv('ExpResults/TabResCorr10_6000_9000mindistSoloGiro.csv')
rsl30md = rsl30md.T.reset_index()
rsl30md.columns= ['Distancia', 'Puntos encontrados promedio', 'Puntos genuinos encontrados promedio', 'Número de emparejamientos que se podrían vulnerar', 'Iteraciones promedio necesarias para vulnerar']
rsl30md = rsl30md[1:]
rsl30md = rsl30md.round({'Distancia':3, 'Puntos encontrados promedio':3, 'Puntos genuinos encontrados promedio':3, 'Número de emparejamientos que se podrían vulnerar':3, 'Iteraciones promedio necesarias para vulnerar':3})

frames = [rsl10md, rsl20md, rsl30md]

dfs = pd.concat(frames)
dfs = dfs.reset_index().drop(['index'], axis=1)
dfs
# Out:
#            Distancia  Puntos encontrados promedio  \
# 0               1000                         15.0
# 1   1222.22222222222                         18.0
# 2   1444.44444444444                         20.0
# 3   1666.66666666667                         22.0
# 4   1888.88888888889                         24.0
# 5   2111.11111111111                         27.0
# 6   2333.33333333333                         30.0
# 7   2555.55555555556                         33.0
# 8   2777.77777777778                         36.0
# 9               3000                         38.0
# 10  3333.33333333333                         42.0
# 11  3666.66666666667                         46.0
# 12              4000                         49.0
# 13  4333.33333333333                         53.0
# 14  4666.66666666667                         56.0
# 15              5000                         59.0
# 16  5333.33333333333                         61.0
# 17  5666.66666666667                         63.0
# ...

# %%
help(groupedBarPlot)
# Out:
# Help on function groupedBarPlot in module PlotUtils:
#
# groupedBarPlot(data, xticks, title, legend=True, axislabels=False, width=0.35, figsize=(25, 10), png=False, pdf=False, colors=None, lg=False, fsizes=False, adBL=False, xtick_rot=False, axisLim=False)
#     Width recomendado para 2 barras agrupadas es 0.35, para 3 y 4 es 0.2

# %%
labels = ['Distance: {}'.format(round(float(i))) for i in dfs['Distancia']]
data =  list(dfs['Puntos encontrados promedio'])
title = 'Genuine + Chaff Matching Points'
donutPlot(data,labels,title)

xticks = [round(float(i)) for i in dfs['Distancia']]
data = {'MatchingPoints':list(dfs['Puntos encontrados promedio'])}
title = 'Genuine + Chaff Matching Points'
cp = ['#8C6D31', '#ffdd6b', '#e9e2c9', '#dcae52', '#af7132', '#8C9363', '#637939', '#AD494A', '#E7969C', '#C4CBB9']
groupedBarPlot(data,xticks,title, legend = False,figsize=(12.5,10),width = 0.7, axislabels=['Distances','Matching Points'], xtick_rot = 90, fsizes={'axes':25,'xtick':22, 'ytick':22, 'font':15}, colors = cp)

# %%
labels = ['Distancia: {}'.format(round(float(i))) for i in dfs['Distancia']]
data =  list(dfs['Puntos genuinos encontrados promedio'])
title = 'Genuine Matching Points'
donutPlot(data,labels,title)

xticks = [round(float(i)) for i in dfs['Distancia']]
data = {'MatchingPoints':list(dfs['Puntos genuinos encontrados promedio'])}
groupedBarPlot(data,xticks,title, legend = False,figsize=(12.5,10),width = 0.7, axislabels=['Distances','Matching Points'], xtick_rot = 90, fsizes={'axes':25,'xtick':22, 'ytick':22, 'font':15}, colors = cp)

# %%
labels = ['Distancia: {}'.format(round(float(i))) for i in dfs['Distancia']]
data =  list(dfs['Número de emparejamientos que se podrían vulnerar'])
title = 'Vault Pairings To Be Breached'
donutPlot(data,labels,title)

xticks = [round(float(i)) for i in dfs['Distancia']]
data = {'MatchingPoints':list(dfs['Número de emparejamientos que se podrían vulnerar'])}
groupedBarPlot(data,xticks,title, legend = False,figsize=(12.5,10),width = 0.7, axislabels=['Distances','Vault Pairings'], xtick_rot = 90, fsizes={'axes':25,'xtick':22, 'ytick':22, 'font':15}, colors = cp)

# %%
labels = ['Distancia: {}'.format(round(float(i))) for i in dfs['Distancia']]
data =  list(dfs['Iteraciones promedio necesarias para vulnerar'])
title = 'Average Iterations Needed To Breach a Pairing'
donutPlot(data,labels,title,legend=False)

xticks = [round(float(i)) for i in dfs['Distancia']]
data = {'MatchingPoints':list(dfs['Iteraciones promedio necesarias para vulnerar'])}
groupedBarPlot(data,xticks,title, legend = False,figsize=(12.5,10),width = 0.7, axislabels=['Distances','Average Number of iterations'], xtick_rot = 90, fsizes={'axes':25,'xtick':22, 'ytick':22, 'font':11}, colors = cp)

# %%
help(donutPlot)
# Out:
# Help on function donutPlot in module PlotUtils:
#
# donutPlot(data, recipe, title=False, png=False, pdf=False, legend=True, figsize=(18, 9))

# %% [markdown]
# ### Resultados Con Translaciones

# %%
rt10md = pd.read_csv('ExpResults/TabResCorr10mindist250trans.csv')
rt10md = rt10md.T.reset_index()
rt10md.columns= ['Distancia', 'Puntos encontrados promedio', 'Puntos genuinos encontrados promedio', 'Número de emparejamientos que se podrían vulnerar', 'Iteraciones promedio necesarias para vulnerar']
rt10md = rt10md.round({'Distancia':3, 'Puntos encontrados promedio':3, 'Puntos genuinos encontrados promedio':3, 'Número de emparejamientos que se podrían vulnerar':3, 'Iteraciones promedio necesarias para vulnerar':3})

rt20md = pd.read_csv('ExpResults/TabResCorr5mindist1000trans.csv')
rt20md = rt20md.T.reset_index()
rt20md.columns= ['Distancia', 'Puntos encontrados promedio', 'Puntos genuinos encontrados promedio', 'Número de emparejamientos que se podrían vulnerar', 'Iteraciones promedio necesarias para vulnerar']
# rt20md = rt20md[1:]
rt20md = rt20md.round({'Distancia':3, 'Puntos encontrados promedio':3, 'Puntos genuinos encontrados promedio':3, 'Número de emparejamientos que se podrían vulnerar':3, 'Iteraciones promedio necesarias para vulnerar':3})

rt30md = pd.read_csv('ExpResults/TabResCorr3mindist1500trans.csv')
rt30md = rt30md.T.reset_index()
rt30md.columns= ['Distancia', 'Puntos encontrados promedio', 'Puntos genuinos encontrados promedio', 'Número de emparejamientos que se podrían vulnerar', 'Iteraciones promedio necesarias para vulnerar']
# rt30md = rt30md[1:]
rt30md = rt30md.round({'Distancia':3, 'Puntos encontrados promedio':3, 'Puntos genuinos encontrados promedio':3, 'Número de emparejamientos que se podrían vulnerar':3, 'Iteraciones promedio necesarias para vulnerar':3})

frames = [rt10md, rt20md, rt30md]

dfs = pd.concat(frames)
dfs = dfs.reset_index().drop(['index'], axis=1)

cp = ['#8C6D31', '#ffdd6b', '#e9e2c9', '#dcae52', '#af7132', '#8C9363', '#637939', '#AD494A', '#E7969C', '#C4CBB9']
colors = []
for i in range(len(dfs)):
    if i < len(rt10md):
        colors.append(cp[5])
    elif i < len(rt10md)+len(rt20md):
        colors.append(cp[3])
    else:
        colors.append(cp[2])

dfs
# Out:
#            Distancia  Puntos encontrados promedio  \
# 0               1000                         17.0
# 1   1222.22222222222                         17.0
# 2   1444.44444444444                         20.0
# 3   1666.66666666667                         22.0
# 4   1888.88888888889                         24.0
# 5   2111.11111111111                         27.0
# 6   2333.33333333333                         30.0
# 7   2555.55555555556                         33.0
# 8   2777.77777777778                         36.0
# 9               3000                         39.0
# 10              2500                         33.0
# 11              2875                         37.0
# 12              3250                         41.0
# 13              3625                         46.0
# 14              4000                         50.0
# 15              4250                         52.0
# 16              4875                         58.0
# 17              5500                         62.0
#
# ...

# %%
xticks = [round(float(i)) for i in dfs['Distancia']]
data = {'250 Translations':list(rt10md['Puntos encontrados promedio']),
        '1000 Translations':list(rt20md['Puntos encontrados promedio']),
        '1500 Translations':list(rt30md['Puntos encontrados promedio'])}
title = 'Genuine + Chaff Matching Points'
groupedBarPlot(data,xticks,title, legend = True,figsize=(12.5,10),width = 0.7,axislabels=['Distances','Matching Points'], colors = colors, lg=True, xtick_rot = 90, fsizes={'axes':25,'xtick':22, 'ytick':22, 'font':15})

# %%
xticks = [round(float(i)) for i in dfs['Distancia']]
data = {'250 Translations':list(rt10md['Puntos genuinos encontrados promedio']),
        '1000 Translations':list(rt20md['Puntos genuinos encontrados promedio']),
        '1500 Translations':list(rt30md['Puntos genuinos encontrados promedio'])}
title = 'Genuine Matching Points'
groupedBarPlot(data,xticks,title, legend = True,figsize=(12.5,10),width = 0.7,axislabels=['Distances','Matching Points'], colors = colors, lg=True, xtick_rot = 90, fsizes={'axes':25,'xtick':22, 'ytick':22, 'font':15})

# %%
xticks = [round(float(i)) for i in dfs['Distancia']]
data = {'250 Translations':list(rt10md['Número de emparejamientos que se podrían vulnerar']),
        '1000 Translations':list(rt20md['Número de emparejamientos que se podrían vulnerar']),
        '1500 Translations':list(rt30md['Número de emparejamientos que se podrían vulnerar'])}
title = 'Vault Pairings To Be Breached'
groupedBarPlot(data,xticks,title, legend = True,figsize=(12.5,10),width = 0.7,axislabels=['Distances','Vault Pairings'], colors = colors, lg=True, xtick_rot = 90, fsizes={'axes':25,'xtick':22, 'ytick':22, 'font':15})

# %%
xticks = [round(float(i)) for i in dfs['Distancia']]
data = {'250 Translations':list(rt10md['Iteraciones promedio necesarias para vulnerar']),
        '1000 Translations':list(rt20md['Iteraciones promedio necesarias para vulnerar']),
        '1500 Translations':list(rt30md['Iteraciones promedio necesarias para vulnerar'])}
title = 'Average Iterations Needed To Breach a Pairing'
groupedBarPlot(data,xticks,title, legend = True,figsize=(12.5,10),width = 0.7,axislabels=['Distances','Average Number of Iterations'], colors = colors, lg=True, xtick_rot = 90, fsizes={'axes':25,'xtick':22, 'ytick':22, 'font':10})

# %% [markdown]
# # Reducciones de Tiempo

# %%
dec = pd.read_csv('Huellas 106_6 y 106_7 dist 1800.csv')
dec.columns = ['Iteración real', 'Iteración permutada']

timesR = []
timesP = []
timesdiff = []
for i in range(len(dec)):
    timesR.append(((dec['Iteración real'][i]/1000)*23.5)/60)
    timesP.append(((dec['Iteración permutada'][i]/1000)*23.5)/60)
    timesdiff.append((timesP[i]-timesR[i]))
    
dec['Tiempo IR'] = timesR
dec['Tiempo Pr'] = timesP
dec['Dif Tiempo'] = timesdiff
    
# rt10md = rt10md.T.reset_index()
# rt10md.columns= ['Distancia', 'Puntos encontrados promedio', 'Puntos genuinos encontrados promedio', 'Número de emparejamientos que se podrían vulnerar', 'Iteraciones promedio necesarias para vulnerar']
# rt10md = rt10md.round({'Distancia':3, 'Puntos encontrados promedio':3, 'Puntos genuinos encontrados promedio':3, 'Número de emparejamientos que se podrían vulnerar':3, 'Iteraciones promedio necesarias para vulnerar':3})
dec
# Out:
#    Iteración real  Iteración permutada  Tiempo IR  Tiempo Pr  Dif Tiempo
# 0            4765                40138   1.866292  15.720717   13.854425
# 1            3221                40139   1.261558  15.721108   14.459550
# 2             944               157671   0.369733  61.754475   61.384742
# 3            2193                46021   0.858925  18.024892   17.165967
# 4           11488                45545   4.499467  17.838458   13.338992
# 5            1418                43018   0.555383  16.848717   16.293333
# 6            3111                40440   1.218475  15.839000   14.620525
# 7            1986               138366   0.777850  54.193350   53.415500
# 8            1327                63490   0.519742  24.866917   24.347175

# %%
dec = pd.read_csv('Huellas 104_6 y 104_8 dist 1800.csv')
dec.columns = ['Iteración real', 'Iteración permutada']

timesR = []
timesP = []
timesdiff = []
for i in range(len(dec)):
    timesR.append(((dec['Iteración real'][i]/1000)*23.5)/60)
    timesP.append(((dec['Iteración permutada'][i]/1000)*23.5)/60)
    timesdiff.append((timesP[i]-timesR[i]))
    
dec['Tiempo IR'] = timesR
dec['Tiempo Pr'] = timesP
dec['Dif Tiempo'] = timesdiff
    
# rt10md = rt10md.T.reset_index()
# rt10md.columns= ['Distancia', 'Puntos encontrados promedio', 'Puntos genuinos encontrados promedio', 'Número de emparejamientos que se podrían vulnerar', 'Iteraciones promedio necesarias para vulnerar']
# rt10md = rt10md.round({'Distancia':3, 'Puntos encontrados promedio':3, 'Puntos genuinos encontrados promedio':3, 'Número de emparejamientos que se podrían vulnerar':3, 'Iteraciones promedio necesarias para vulnerar':3})
dec
# Out:
#    Iteración real  Iteración permutada   Tiempo IR    Tiempo Pr   Dif Tiempo
# 0             519             10511509    0.203275  4117.007692  4116.804417
# 1            2732             12320884    1.070033  4825.679567  4824.609533
# 2             571             12614813    0.223642  4940.801758  4940.578117
# 3            1341              5359993    0.525225  2099.330592  2098.805367
# 4          297908              1449877  116.680633   567.868492   451.187858
# 5            1999              6330510    0.782942  2479.449750  2478.666808
# 6            1195             10186370    0.468042  3989.661583  3989.193542
# 7            2658              5576341    1.041050  2184.066892  2183.025842
# 8              60              5560194    0.023500  2177.742650  2177.719150
# 9             148             10243951    0.057967  4012.214142  4012.156175

# %%
((dec['Iteración permutada'][0]/1000)*23.5)/60
# Out:
# 4117.007691666667
